# %%
print("Hello World")
# Out:
# Hello World

# %%
s = 4
t = 2 
s*t
# Out:
# 8

# %%
import numpy
import pandas
import matplotlib.pylab as plt

# %%
plt.plot([1,2,3], [4,5,6])

# %%
plt.scatter([1,2,3], [4,5,6])

# %%
# print random number
import random

print(random.randint(0,100))
# Out:
# 25
